# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = r"https://github.com/edyoda/data-science-complete-tutorial/blob/master/Data/house_rental_data.csv.txt"

# %%
df = pd.read_csv("https://raw.githubusercontent.com/zekelabs/data-science-complete-tutorial/master/Data/house_rental_data.csv.txt", index_col='Unnamed: 0')

# %%
df.head()
# Out:
#        Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom  Price
# 1  1177.698      2           7        2            2         2  62000
# 2  2134.800      5           7        4            2         2  78000
# 3  1138.560      5           7        2            2         1  58000
# 4  1458.780      2           7        3            2         2  45000
# 5   967.776     11          14        3            2         2  45000

# %%
df.shape
# Out:
# (645, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 645 entries, 1 to 648
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sqft         645 non-null    float64
#  1   Floor        645 non-null    int64
#  2   TotalFloor   645 non-null    int64
#  3   Bedroom      645 non-null    int64
#  4   Living.Room  645 non-null    int64
#  5   Bathroom     645 non-null    int64
#  6   Price        645 non-null    int64
# dtypes: float64(1), int64(6)
# memory usage: 40.3 KB

# %%
df.isnull().sum()
# Out:
# Sqft           0
# Floor          0
# TotalFloor     0
# Bedroom        0
# Living.Room    0
# Bathroom       0
# Price          0
# dtype: int64

# %%
df.describe()
# Out:
#               Sqft       Floor  TotalFloor     Bedroom  Living.Room  \
# count   645.000000  645.000000  645.000000  645.000000   645.000000
# mean   1527.656260    5.939535   10.855814    2.837209     1.813953
# std     767.386531    3.884721    4.996208    1.010740     0.462364
# min     359.358000    1.000000    1.000000    1.000000     0.000000
# 25%     925.080000    3.000000    7.000000    2.000000     2.000000
# 50%    1423.200000    5.000000   12.000000    3.000000     2.000000
# 75%    1892.856000    8.000000   14.000000    4.000000     2.000000
# max    5856.468000   22.000000   38.000000    7.000000     4.000000
#
#          Bathroom          Price
# count  645.000000     645.000000
# mean     1.810853   61986.823256
# std      0.683574   35635.091007
# min      0.000000    6100.000000
# 25%      1.000000   39000.000000
# 50%      2.000000   50000.000000
# 75%      2.000000   75000.000000
# max      5.000000  250000.000000

# %%
df[df.duplicated()]
# Out:
#          Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom   Price
# 22   2768.124      6          19        3            2         2  100000
# 27   3664.740     19          19        3            2         3  200000
# 33   2134.800     10          19        3            2         2   55000
# 49   3735.900     19          19        3            2         3  200000
# 100  2063.640      5           7        4            2         2   70000
# ..        ...    ...         ...      ...          ...       ...     ...
# 614  2134.800      3           6        4            2         3   98000
# 618   711.600      8          14        1            1         1   36000
# 634  1167.024      2          12        3            2         2   38000
# 642  1707.840      9          15        3            2         2   80000
# 647  1707.840      3          14        3            2         2   65000
#
# [66 rows x 7 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Sqft, Floor, TotalFloor, Bedroom, Living.Room, Bathroom, Price]
# Index: []

# %%
df.dtypes
# Out:
# Sqft           float64
# Floor            int64
# TotalFloor       int64
# Bedroom          int64
# Living.Room      int64
# Bathroom         int64
# Price            int64
# dtype: object

# %%
sns.pairplot(df, diag_kind = "kde")

# %%
sns.jointplot(data=df, x="Sqft", y="Price")

# %%
df.corr()
# Out:
#                  Sqft     Floor  TotalFloor   Bedroom  Living.Room  Bathroom  \
# Sqft         1.000000  0.118568    0.304795  0.613589     0.458412  0.725545
# Floor        0.118568  1.000000    0.552552  0.039165    -0.025554  0.088359
# TotalFloor   0.304795  0.552552    1.000000  0.079984     0.023659  0.141258
# Bedroom      0.613589  0.039165    0.079984  1.000000     0.527463  0.650881
# Living.Room  0.458412 -0.025554    0.023659  0.527463     1.000000  0.559363
# Bathroom     0.725545  0.088359    0.141258  0.650881     0.559363  1.000000
# Price        0.823781  0.226952    0.336982  0.465091     0.332643  0.604204
#
#                 Price
# Sqft         0.823781
# Floor        0.226952
# TotalFloor   0.336982
# Bedroom      0.465091
# Living.Room  0.332643
# Bathroom     0.604204
# Price        1.000000

# %%
sns.heatmap(df.corr())

# %%
x = df.drop("Price",axis=1).values   #independent
y = df["Price"].values   #target or dependent

# %%
x
# Out:
# array([[1.177698e+03, 2.000000e+00, 7.000000e+00, 2.000000e+00,
#         2.000000e+00, 2.000000e+00],
#        [2.134800e+03, 5.000000e+00, 7.000000e+00, 4.000000e+00,
#         2.000000e+00, 2.000000e+00],
#        [1.138560e+03, 5.000000e+00, 7.000000e+00, 2.000000e+00,
#         2.000000e+00, 1.000000e+00],
#        ...,
#        [3.771480e+02, 4.000000e+00, 1.000000e+01, 1.000000e+00,
#         1.000000e+00, 1.000000e+00],
#        [7.400640e+02, 1.300000e+01, 1.400000e+01, 1.000000e+00,
#         1.000000e+00, 1.000000e+00],
#        [1.376946e+03, 6.000000e+00, 7.000000e+00, 3.000000e+00,
#         2.000000e+00, 1.000000e+00]])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y , test_size=0.4)

# %%
x_train.shape
# Out:
# (347, 6)

# %%
y_train.shape
# Out:
# (347,)

# %%
x_test.shape
# Out:
# (232, 6)

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from math import ceil, sqrt

# %%
knr = KNeighborsRegressor()
knr.fit(x_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred = knr.predict(x_test)

# %%
sqrt(mean_squared_error(y_true = y_test, y_pred = y_pred))
# Out:
# 21847.810664268494

# %%
c = ceil(sqrt(df.shape[0]))

# %%
for i in range(0, c+1):
    model = KNeighborsRegressor()
    model.fit(x_train, y_train)
    y_test_pred = model.predict(x_test)
    error = sqrt(mean_squared_error(y_test, y_test_pred))
    print(i , error)
# Out:
# 0 21847.810664268494
# 1 21847.810664268494
# 2 21847.810664268494
# 3 21847.810664268494
# 4 21847.810664268494
# 5 21847.810664268494
# 6 21847.810664268494
# 7 21847.810664268494
# 8 21847.810664268494
# 9 21847.810664268494
# 10 21847.810664268494
# 11 21847.810664268494
# 12 21847.810664268494
# 13 21847.810664268494
# 14 21847.810664268494
# 15 21847.810664268494
# 16 21847.810664268494
# 17 21847.810664268494
# 18 21847.810664268494
# 19 21847.810664268494
# 20 21847.810664268494
# 21 21847.810664268494
# 22 21847.810664268494
# 23 21847.810664268494
# 24 21847.810664268494
# 25 21847.810664268494
